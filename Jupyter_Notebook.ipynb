# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## Proyecto Final de Ciencia de Datos

# %% [markdown]
# ## Introducción
# En este cuaderno, se presentarán algunos ejemplos prácticos relacionados con la ciencia de datos utilizando JupyterLite.

# %% [markdown]
# ## Lenguajes de Ciencia de Datos
# Los principales lenguajes utilizados en ciencia de datos son:
# - Python
# - R
# - SQL
# - Scala

# %% [markdown]
# ## Bibliotecas de Ciencia de Datos
# Algunas de las bibliotecas más importantes de ciencia de datos incluyen:
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn

# %% [markdown]
# ## Herramientas de Ciencia de Datos
# | Herramienta             | Descripción                                     |
# |-------------------------|-------------------------------------------------|
# | Jupyter Notebooks        | Entorno interactivo de ciencia de datos         |
# | RStudio                 | Entorno de desarrollo para R                    |
# | TensorFlow              | Biblioteca para machine learning                |
# | Apache Spark            | Procesamiento distribuido de grandes datos      |

# %% [markdown]
# ## Ejemplos de Expresiones Aritméticas
# En Python podemos realizar operaciones como:
# - Suma: `5 + 5`
# - Multiplicación: `10 * 2`

# %%
# Código para sumar y multiplicar
suma = 5 + 5
multiplicacion = 10 * 2
suma, multiplicacion
# Out:
# (10, 20)

# %%
# Convertir minutos a horas
minutos = 120
horas = minutos / 60
horas
# Out:
# 2.0

# %% [markdown]
# ## Objetivos del Proyecto
# Los objetivos de este cuaderno son:
# 1. Demostrar el uso de Markdown para documentar el cuaderno.
# 2. Realizar operaciones matemáticas básicas en Python.
# 3. Visualizar cómo se pueden usar celdas de código y Markdown para la ciencia de datos.

# %% [markdown]
# **Autor:** [Hector]
